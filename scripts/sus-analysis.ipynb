# %% [markdown]
# # Análisis de usabilidad SUS — SGROAS
# **Bloque C.3** | `scripts/sus-analysis.py` (Brooke 1996) | n=10 (P01..P10) | `docs/mediciones/sus/`
# Replica `python scripts/sus-analysis.py`. Puntuación Brooke por participante, media, DT, IC95 (t de Student), escala adjetiva Bangor et al. 2009.

# %%
import json, pathlib
p = pathlib.Path('docs/mediciones/sus/estadisticas-sus.json')
print(json.dumps(json.loads(p.read_text(encoding='utf-8')), indent=2, ensure_ascii=False))
# Out:
# Cargados 10 participantes (sus-raw.csv). Media SUS 63.0  DT 13.88  IC95 [53.07; 72.93]  Adjetiva: OK  Zona: marginal  Umbral 70: NO CUMPLE
# Generados: P01..P10.json, estadisticas-sus.json, estadisticas-item.json, ANALISIS-SUS.md, figuras/

# %% [markdown]
# Figura `fig-sus-por-participante.png`: barras por participante, media, banda IC95 y umbral 70. Paleta Okabe-Ito.

# %%
from IPython.display import Image
Image('docs/mediciones/sus/figuras/fig-sus-por-participante.png')
